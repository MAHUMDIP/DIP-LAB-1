# %%
#Reading Tiff Images

import rasterio
from rasterio.plot import show
from PIL import Image
img = Image.open("C:\\Users\\Syscom\\Desktop\\Digital image processing images\\HH-ALPSRP247640510-H2.2_UA.tif")
show(img)
pixels = img.load()

# %%
pip install rasterio
# Out:
# ...
#   Obtaining dependency information for rasterio from https://files.pythonhosted.org/packages/b3/0f/e7f21b87636029955ab4e0e81027dc491d99c2b6215e68c6d8f38e5291b3/rasterio-1.3.9-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/23.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/23.4 MB 1.4 MB/s eta 0:00:18
#    ---------------------------------------- 0.0/23.4 MB 330.3 kB/s eta 0:01:11
#    ---------------------------------------- 0.1/23.4 MB 438.9 kB/s eta 0:00:54
#    ---------------------------------------- 0.1/23.4 MB 438.9 kB/s eta 0:00:54
#    ---------------------------------------- 0.1/23.4 MB 375.8 kB/s eta 0:01:02
#    ---------------------------------------- 0.1/23.4 MB 375.8 kB/s eta 0:01:02
#    ---------------------------------------- 0.1/23.4 MB 375.8 kB/s eta 0:01:02
#    ---------------------------------------- 0.1/23.4 MB 252.2 kB/s eta 0:01:33
# ...

# %%
import rasterio

# Open the GeoTIFF image
with rasterio.open("C:\\Users\\Syscom\\Desktop\\Digital image processing images\\HH-ALPSRP247640510-H2.2_UA.tif") as dataset:
    # Check the size (dimensions)
    width = dataset.width
    height = dataset.height
    print("Image Size (Width x Height):", width, "x", height)

    # Check the number of bands
    num_bands = dataset.count
    print("Number of Bands:", num_bands)
# Out:
# Image Size (Width x Height): 5600 x 4700
# Number of Bands: 1

# %%
dataset.count
dataset.width
dataset.height
# Out:
# 4700

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
import numpy as np
from PIL import Image

# Open the image
img = Image.open("C:\\Users\\Syscom\\Desktop\\Digital image processing images\\HH-ALPSRP247640510-H2.2_UA.tif")


# Convert the image to a NumPy array
img_array = np.array(img)

# Calculate image statistics
mean = np.mean(img_array)
std_dev = np.std(img_array)
min = np.min(img_array)
max = np.max(img_array)

# Print the results
print("Mean:", mean)
print("Standard Deviation:", std_dev)
print("Min:", min)
print("Max:", max)
# Out:
# Mean: 3726.1503949468083
# Standard Deviation: 2051.284029960794
# Min: 0
# Max: 65535

# %%
width, height = img.size

# Print the results
print("Width:", width)
print("Height:", height)
# Out:
# Width: 5600
# Height: 4700

# %%
#Reducing Size of the image
import matplotlib.pyplot as plt
import cv2
import numpy as np

 
try:
    img = cv2.imread("C:\\Users\\Syscom\\Desktop\\Digital image processing images\\HH-ALPSRP247640510-H2.2_UA.tif") 
    (height, width) = img.shape[:2]    
    res = cv2.resize(img, (int(width / 4), int(height / 4)), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite('result.tiff', res)
    plt.imshow(res)
 
except IOError:
    print('Error while reading files !!!')

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
pip install opencv-python
# Out:
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/38/d2/3e8c13ffc37ca5ebc6f382b242b44acb43eb489042e1728407ac3904e72f/opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.1 MB 330.3 kB/s eta 0:01:56
#    ---------------------------------------- 0.0/38.1 MB 219.4 kB/s eta 0:02:54
#    ---------------------------------------- 0.1/38.1 MB 328.2 kB/s eta 0:01:56
#    ---------------------------------------- 0.1/38.1 MB 327.7 kB/s eta 0:01:56
#    ---------------------------------------- 0.1/38.1 MB 327.7 kB/s eta 0:01:56
#    ---------------------------------------- 0.1/38.1 MB 327.7 kB/s eta 0:01:56
#    ---------------------------------------- 0.1/38.1 MB 327.7 kB/s eta 0:01:56
# ...

# %%
#Rotating Tiff Images
try:
    img = cv2.imread("C:\\Users\\Syscom\\Desktop\\Digital image processing images\\HH-ALPSRP247640510-H2.2_UA.tif") 

    (rows, cols) = img.shape[:2]
    M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 180, 1)
    res1 = cv2.warpAffine(img, M, (cols, rows))
    cv2.imwrite('result.tiff', res1)
    plt.imshow(res1)
except IOError:
    print('Error while reading files !!!')

# %%
#Translating Matrix
M = np.float32([[1, 0, 100], [0, 1, 50]])
try:
    img = cv2.imread("C:\\Users\\Syscom\\Desktop\\Digital image processing images\\HH-ALPSRP247640510-H2.2_UA.tif")
    res2 = cv2.warpAffine(img, M, (cols, rows))
    cv2.imwrite('result.tiff', res2)
    plt.imshow(res2)
 
except IOError:
    print('Error while reading files !!!')

# %%
#Canny Edge Detection
try:
    img = cv2.imread("C:\\Users\\Syscom\\Desktop\\Digital image processing images\\HH-ALPSRP247640510-H2.2_UA.tif")
    edges = cv2.Canny(img, 20, 14)
    cv2.imwrite('result.tiff', edges)
    plt.imshow(edges)

except IOError:
    print('Error while reading files !!!')

# %%
#RGB
import cv2
import matplotlib.pyplot as plt

img2 = cv2.imread("C:\\Users\\Syscom\\Desktop\\Digital image processing images\\HH-ALPSRP247640510-H2.2_UA.tif")
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

plt.imshow(img2_rgb)
plt.axis('off')  
plt.show()
